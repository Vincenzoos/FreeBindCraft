# %% [markdown]
# # BindCraft Interactive UI
#
# This notebook is a thin launcher for the FreeBindCraft ipywidgets interface.

# %%
# %pip install -q 'ipywidgets>=8' jupyterlab_widgets widgetsnbextension
import ipywidgets
print(f'ipywidgets {ipywidgets.__version__} OK')

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / 'main_UI.py').exists():
    ROOT = Path('/storage/viet/FreeBindCraft').resolve()
sys.path.insert(0, str(ROOT))

from main_UI import launch_all_ui
launch_all_ui()

# %% [markdown]
# ## Optional: archive outputs
#
# After a job completes, archive output files from the repository root if needed, for example `zip -r outputs.zip outputs`.

# %% [markdown]
# # FreeBindCraft Interactive UI

# %%
# %pip install -q 'ipywidgets>=8' jupyterlab_widgets widgetsnbextension
import ipywidgets
print(f'ipywidgets {ipywidgets.__version__} OK')
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ipywidgets 8.1.8 OK

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
if not (ROOT / 'main_UI.py').exists():
    ROOT = Path('/storage/viet/FreeBindCraft').resolve()
sys.path.insert(0, str(ROOT))

from main_UI import launch_all_ui

launch_all_ui()
# Out:
# VBox(children=(HTML(value='\n        <div style="background:#e8d5f5;padding:12px 16px;border-radius:6px;margin…

# %%
# !apt-get update
# !apt-get install -y zip unzip
# !cd /workspace
# !zip -r outputs.zip outputs
# Out:
# Reading package lists... Done
# E: Could not open lock file /var/lib/apt/lists/lock - open (13: Permission denied)
# E: Unable to lock directory /var/lib/apt/lists/
# W: Problem unlinking the file /var/cache/apt/pkgcache.bin - RemoveCaches (13: Permission denied)
# W: Problem unlinking the file /var/cache/apt/srcpkgcache.bin - RemoveCaches (13: Permission denied)
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# /bin/bash: line 1: cd: /workspace: No such file or directory
#   adding: outputs/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/freebindcraft_20260722_200005.exit (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/rejected_mpnn_full_stats.csv (deflated 88%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/final_design_stats.csv (deflated 79%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Animation/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Animation.zip (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Plots.zip (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l82_s784100.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l147_s128935.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l110_s619278.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l104_s80430.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l108_s801709.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l76_s408647.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l144_s562969.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l98_s747069.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l66_s492382.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l140_s212121.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l103_s986825.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l128_s448442.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l128_s745474.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l84_s189426.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l95_s438236.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l137_s991311.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l150_s387634.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l73_s65137.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l148_s894381.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l85_s214598.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l114_s461776.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l121_s125397.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l100_s177592.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l71_s801085.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l78_s32966.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l70_s344312.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l94_s382811.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l110_s344531.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l78_s821038.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Clashing/IFIT5_alphafoldmodel-Binder_l101_s833677.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Pickle/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l95_s594200.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l125_s957967.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l80_s908504.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l86_s862094.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l112_s97073.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l145_s677715.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l76_s45187.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l69_s988271.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l108_s71303.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/LowConfidence/IFIT5_alphafoldmodel-Binder_l88_s295642.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l114_s953527.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l129_s852897.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l79_s805914.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l68_s820325.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l113_s311747.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l149_s52936.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l75_s767597.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l122_s389876.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l87_s710320.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l138_s847109.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_l129_s427762.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Trajectory/Relaxed/IFIT5_alphafoldmodel-Binder_
model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/MPNN/Relaxed/IFIT5_alphafoldmodel-Binder_l66_s962527_mpnn2_model1.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/MPNN/Relaxed/IFIT5_alphafoldmodel-Binder_l79_s805914_mpnn1_model1.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/MPNN/Relaxed/IFIT5_alphafoldmodel-Binder_l69_s341653_mpnn19_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/MPNN/Relaxed/IFIT5_alphafoldmodel-Binder_l98_s187878_mpnn8_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/MPNN/Relaxed/IFIT5_alphafoldmodel-Binder_l98_s187878_mpnn17_model1.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/MPNN/Relaxed/IFIT5_alphafoldmodel-Binder_l78_s232434_mpnn4_model1.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/MPNN/Sequences/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/trajectory_stats.csv (deflated 70%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/freebindcraft_20260722_200005.log (deflated 84%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/freebindcraft_20260722_152721.log (deflated 84%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l68_s820325_mpnn1_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l87_s710320_mpnn4_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l75_s767597_mpnn4_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Animation/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Animation/IFIT5_alphafoldmodel-Binder_l147_s411684.html (deflated 24%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Animation/IFIT5_alphafoldmodel-Binder_l78_s232434.html (deflated 24%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Animation/IFIT5_alphafoldmodel-Binder_l75_s767597.html (deflated 24%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Animation/IFIT5_alphafoldmodel-Binder_l68_s820325.html (deflated 24%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Animation/IFIT5_alphafoldmodel-Binder_l79_s805914.html (deflated 24%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Animation/IFIT5_alphafoldmodel-Binder_l87_s710320.html (deflated 24%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l147_s411684_mpnn3_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l68_s820325_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l75_s767597_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l147_s411684_mpnn4_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Pickle/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l87_s710320_mpnn3_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l78_s232434_mpnn3_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l79_s805914_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/IFIT5_alphafoldmodel-Binder_l79_s805914_mpnn1_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/9_IFIT5_alphafoldmodel-Binder_l75_s767597_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/11_IFIT5_alphafoldmodel-Binder_l68_s820325_mpnn1_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/7_IFIT5_alphafoldmodel-Binder_l147_s411684_mpnn4_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/10_IFIT5_alphafoldmodel-Binder_l147_s411684_mpnn3_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/8_IFIT5_alphafoldmodel-Binder_l75_s767597_mpnn4_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/4_IFIT5_alphafoldmodel-Binder_l79_s805914_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/2_IFIT5_alphafoldmodel-Binder_l87_s710320_mpnn4_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/6_IFIT5_alphafoldmodel-Binder_l68_s820325_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/5_IFIT5_alphafoldmodel-Binder_l78_s232434_mpnn3_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/1_IFIT5_alphafoldmodel-Binder_l87_s710320_mpnn3_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Ranked/3_IFIT5_alphafoldmodel-Binder_l79_s805914_mpnn1_model2.pdb (deflated 78%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/ (stored 0%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l78_s232434_i_ptm.png (deflated 6%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l87_s710320_con.png (deflated 6%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l68_s820325_loss.png (deflated 8%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l79_s805914_plddt.png (deflated 7%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l147_s411684_pae.png (deflated 10%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l87_s710320_pae.png (deflated 9%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l78_s232434_con.png (deflated 7%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l79_s805914_i_pae.png (deflated 8%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l87_s710320_ptm.png (deflated 6%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l147_s411684_ptm.png (deflated 8%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_l79_s805914_i_ptm.png (deflated 7%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/Accepted/Plots/IFIT5_alphafoldmodel-Binder_
)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/run_command.sh (deflated 58%)
#   adding: outputs/IFIT5_alphafoldmodel_freebindcraft/mpnn_design_stats.csv (deflated 85%)
#   adding: outputs/PD1_freebindcraft/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/rejected_mpnn_full_stats.csv (deflated 83%)
#   adding: outputs/PD1_freebindcraft/final_design_stats.csv (deflated 77%)
#   adding: outputs/PD1_freebindcraft/Trajectory/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Animation/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Animation.zip (stored 0%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Plots.zip (stored 0%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Clashing/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Clashing/PD1-binder_l147_s642894.pdb (deflated 77%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Clashing/PD1-binder_l144_s657165.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Clashing/PD1-binder_l143_s526063.pdb (deflated 77%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Pickle/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Trajectory/LowConfidence/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Relaxed/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Relaxed/PD1-binder_l88_s827427.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Relaxed/PD1-binder_l75_s330957.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Relaxed/PD1-binder_l117_s834129.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Relaxed/PD1-binder_l110_s198734.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Trajectory/Plots/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/failure_csv.csv (deflated 65%)
#   adding: outputs/PD1_freebindcraft/interactive_PD1-binder_20260713_171241.json (deflated 38%)
#   adding: outputs/PD1_freebindcraft/MPNN/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/MPNN/Binder/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l117_s834129_mpnn1_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn8_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l75_s330957_mpnn10_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn5_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn15_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l88_s827427_mpnn1_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l88_s827427_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l75_s330957_mpnn5_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l117_s834129_mpnn1_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l75_s330957_mpnn3_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn18_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l75_s330957_mpnn10_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l88_s827427_mpnn1_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn20_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l117_s834129_mpnn2_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn20_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn5_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l88_s827427_mpnn2_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn18_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l117_s834129_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l75_s330957_mpnn5_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn15_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l110_s198734_mpnn8_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Relaxed/PD1-binder_l75_s330957_mpnn3_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/MPNN/Sequences/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/trajectory_stats.csv (deflated 57%)
#   adding: outputs/PD1_freebindcraft/Accepted/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Accepted/PD1-binder_l117_s834129_mpnn1_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Animation/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Accepted/Animation/PD1-binder_l117_s834129.html (deflated 24%)
#   adding: outputs/PD1_freebindcraft/Accepted/Animation/PD1-binder_l88_s827427.html (deflated 24%)
#   adding: outputs/PD1_freebindcraft/Accepted/Animation/PD1-binder_l75_s330957.html (deflated 24%)
#   adding: outputs/PD1_freebindcraft/Accepted/PD1-binder_l88_s827427_mpnn1_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/PD1-binder_l88_s827427_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/PD1-binder_l75_s330957_mpnn5_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Pickle/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Accepted/PD1-binder_l75_s330957_mpnn10_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/PD1-binder_l117_s834129_mpnn2_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Ranked/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Accepted/Ranked/3_PD1-binder_l117_s834129_mpnn1_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Ranked/4_PD1-binder_l75_s330957_mpnn5_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Ranked/5_PD1-binder_l117_s834129_mpnn2_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Ranked/6_PD1-binder_l75_s330957_mpnn10_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Ranked/1_PD1-binder_l88_s827427_mpnn1_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Ranked/2_PD1-binder_l88_s827427_mpnn2_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_i_ptm.png (deflated 5%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_con.png (deflated 5%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_rg.png (deflated 11%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_loss.png (deflated 7%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_loss.png (deflated 8%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_i_pae.png (deflated 7%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_pae.png (deflated 9%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_plddt.png (deflated 6%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_plddt.png (deflated 5%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_con.png (deflated 5%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_con.png (deflated 6%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_pae.png (deflated 8%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_ptm.png (deflated 6%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_pae.png (deflated 7%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_plddt.png (deflated 6%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_i_con.png (deflated 5%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_i_ptm.png (deflated 4%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_i_con.png (deflated 5%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_i_pae.png (deflated 6%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_i_ptm.png (deflated 5%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l75_s330957_rg.png (deflated 9%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_i_pae.png (deflated 6%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_i_con.png (deflated 5%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l88_s827427_ptm.png (deflated 7%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_loss.png (deflated 7%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_rg.png (deflated 11%)
#   adding: outputs/PD1_freebindcraft/Accepted/Plots/PD1-binder_l117_s834129_ptm.png (deflated 6%)
#   adding: outputs/PD1_freebindcraft/Rejected/ (stored 0%)
#   adding: outputs/PD1_freebindcraft/Rejected/PD1-binder_l110_s198734_mpnn15_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Rejected/PD1-binder_l110_s198734_mpnn20_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Rejected/PD1-binder_l110_s198734_mpnn5_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Rejected/PD1-binder_l110_s198734_mpnn18_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Rejected/PD1-binder_l110_s198734_mpnn8_model2.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/Rejected/PD1-binder_l75_s330957_mpnn3_model1.pdb (deflated 78%)
#   adding: outputs/PD1_freebindcraft/mpnn_design_stats.csv (deflated 78%)

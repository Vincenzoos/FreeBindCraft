# %% [markdown]
# # Step 4: ipSAE Evaluation UI

# %%
# %pip install -q 'ipywidgets>=8' jupyterlab_widgets widgetsnbextension
import ipywidgets
print(f'ipywidgets {ipywidgets.__version__} OK')
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ipywidgets 8.1.8 OK

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
candidate_roots = [ROOT, *ROOT.parents, Path('/storage/viet/FreeBindCraft').resolve()]
ADDITIONS = None
for base in candidate_roots:
    candidate = base / 'dependencies' / 'IPSAE' / 'additions'
    if (candidate / 'ipsae_eval_ui.py').exists():
        ADDITIONS = candidate
        break

if ADDITIONS is None:
    raise FileNotFoundError('Could not find dependencies/IPSAE/additions/ipsae_eval_ui.py')

sys.path.insert(0, str(ADDITIONS))

from ipsae_eval_ui import launch_ipsae_eval_ui

launch_ipsae_eval_ui()
# Out:
# VBox(children=(HTML(value='<div style="background:#e8d5f5;padding:12px 16px;border-radius:6px;margin:8px 0;fon…
# <div style="color:#1a7f37;font-weight:600;;margin:8px 0;font-family:sans-serif">SUCCESS: bulk ipSAE finished for 10/10 model(s).<br/>Logged AF3 folder/model selection to bulk_ipsae_evals_20260727_191734/bulk_ipsae_evals_20260727_191734_log.json<br/>Copied ipSAE outputs to bulk_ipsae_evals_20260727_191734<br/><span style="color:#57606a;">Each model gets 3 files from one run: <code>*_10_10.txt</code> (summary), <code>*_10_10_byres.txt</code> (per-residue), <code>*_10_10.pml</code> (PyMOL). Table rows are score variants per model, not separate models.</span></div>
#                                                 Model  \
# 0   fold_ifit5_1half_altered2_binder_l130_s734871_...
# 1   fold_ifit5_1half_altered2_binder_l130_s734871_...
# 2   fold_ifit5_1half_altered2_binder_l130_s734871_...
# 3   fold_ifit5_1half_altered2_binder_l130_s734871_...
# 4   fold_ifit5_1half_altered2_binder_l130_s734871_...
# 5   fold_ifit5_1half_altered2_binder_l130_s734871_...
# 6   fold_ifit5_1half_altered2_binder_l136_s450785_...
# 7   fold_ifit5_1half_altered2_binder_l136_s450785_...
# 8   fold_ifit5_1half_altered2_binder_l136_s450785_...
# 9   fold_ifit5_1half_altered2_binder_l136_s450785_...
# 10  fold_ifit5_1half_altered2_binder_l136_s450785_...
# 11  fold_ifit5_1half_altered2_binder_l136_s450785_...
# 12  fold_ifit5_1half_altered2_binder_l142_s405521_...
# 13  fold_ifit5_1half_altered2_binder_l142_s405521_...
# 14  fold_ifit5_1half_altered2_binder_l142_s405521_...
# 15  fold_ifit5_1half_altered2_binder_l150_s62602_m...
# 16  fold_ifit5_1half_altered2_binder_l150_s62602_m...
# 17  fold_ifit5_1half_altered2_binder_l150_s62602_m...
# 18  fold_ifit5_1half_altered2_binder_l150_s62602_m...
# 19  fold_ifit5_1half_altered2_binder_l150_s62602_m...
# 20  fold_ifit5_1half_altered2_binder_l150_s62602_m...
# 21  fold_ifit5_1half_altered2_binder_l88_s481314_m...
# 22  fold_ifit5_1half_altered2_binder_l88_s481314_m...
# 23  fold_ifit5_1half_altered2_binder_l88_s481314_m...
# 24  fold_ifit5_1half_altered2_binder_l88_s481314_m...
# 25  fold_ifit5_1half_altered2_binder_l88_s481314_m...
# 26  fold_ifit5_1half_altered2_binder_l88_s481314_m...
# 27  fold_ifit5_with_ifit5_1half_altered2_binder_l1...
# 28  fold_ifit5_with_ifit5_1half_altered2_binder_l1...
# 29  fold_ifit5_with_ifit5_1half_altered2_binder_l1...
#
#                                              PAE_File  \
# 0   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 1   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 2   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 3   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 4   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 5   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 6   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 7   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 8   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 9   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 10  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 11  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 12  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 13  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 14  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 15  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 16  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 17  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 18  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 19  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 20  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 21  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 22  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 23  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 24  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 25  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 26  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 27  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 28  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 29  Cameron IFIT5 binder AlphaFold3 models/fold_if...
#
#                                        Structure_File  \
# 0   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 1   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 2   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 3   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 4   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 5   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 6   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 7   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 8   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 9   Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 10  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 11  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 12  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 13  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 14  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 15  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 16  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 17  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 18  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 19  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 20  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 21  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 22  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 23  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 24  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 25  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 26  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 27  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 28  Cameron IFIT5 binder AlphaFold3 models/fold_if...
# 29  Cameron IFIT5 binder AlphaFold3 models/fold_if...
#
#                                            Score_File  \
# 0   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 1   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 2   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 3   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 4   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 5   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 6   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 7   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 8   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 9   bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 10  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 11  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 12  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 13  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 14  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 15  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 16  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 17  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 18  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 19  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 20  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 21  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 22  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 23  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 24  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 25  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 26  bulk_ipsae_evals_20260727_191734/fold_ifit5_1h...
# 27  bulk_ipsae_evals_20260727_191734/fold_ifit5_wi...
# 28  bulk_ipsae_evals_20260727_191734/fold_ifit5_wi...
# 29  bulk_ipsae_evals_20260727_191734/fold_ifit5_wi...
#
#                      Eval_Output_Dir Chn1 Chn2  PAE  Dist  Type  ...  n0res  \
# 0   bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...    130
# 1   bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...    173
# 2   bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...    130
# 3   bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...    130
# 4   bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...    185
# 5   bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...    130
# 6   bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...    136
# 7   bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...    191
# 8   bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...    136
# 9   bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...      1
# 10  bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...      1
# 11  bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...      1
# 12  bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...      0
# 13  bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...      1
# 14  bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...      1
# 15  bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...    150
# 16  bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...    158
# 17  bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...    150
# 18  bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...    150
# 19  bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...    178
# 20  bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...    150
# 21  bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...     88
# 22  bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...    160
# 23  bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...     88
# 24  bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...     88
# 25  bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...    159
# 26  bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...     88
# 27  bulk_ipsae_evals_20260727_191734    A    B   10    10  asym  ...    140
# 28  bulk_ipsae_evals_20260727_191734    B    A   10    10  asym  ...    175
# 29  bulk_ipsae_evals_20260727_191734    A    B   10    10   max  ...    175
#
#     n0chn  n0dom  d0res  d0chn  d0dom  nres1  nres2  dist1  dist2
# 0     322    272   4.23   6.57   6.08    142    130     28     40
# 1     322    301   4.90   6.57   6.37    124    177     43     30
# 2     322    272   4.23   6.57   6.08    177    130     30     43
# 3     322    271   4.23   6.57   6.07    141    130     27     35
# 4     322    310   5.07   6.57   6.45    125    185     37     27
# 5     322    271   4.23   6.57   6.07    185    130     27     37
# 6     328    281   4.33   6.62   6.17    145    136     32     46
# 7     328    321   5.15   6.62   6.56    130    191     49     33
# 8     328    281   4.33   6.62   6.17    191    136     33     49
# 9     328      2   1.00   6.62   1.00      1      1      1      1
# 10    328     13   1.00   6.62   1.00      9      4      5      3
# 11    328     13   1.00   6.62   1.00      4      9      3      5
# 12    334      0   1.00   6.67   1.00      0      0      0      0
# 13    334      7   1.00   6.67   1.00      4      3      0      0
# 14    334      7   1.00   6.67   1.00      3      4      0      0
# 15    342    289   4.56   6.74   6.25    139    150     35     38
# 16    342    306   4.68   6.74   6.42    147    159     40     37
# 17    342    289   4.56   6.74   6.25    159    150     37     40
# 18    342    293   4.56   6.74   6.29    143    150     36     42
# 19    342    330   4.97   6.74   6.64    149    181     44     36
# 20    342    293   4.56   6.74   6.29    181    150     36     44
# 21    280    231   3.38   6.16   5.64    143     88     33     36
# 22    280    247   4.71   6.16   5.82     87    160     36     33
# 23    280    231   3.38   6.16   5.64    160     88     33     36
# 24    280    233   3.38   6.16   5.66    145     88     31     37
# 25    280    247   4.70   6.16   5.82     87    160     37     31
# 26    280    233   3.38   6.16   5.66    160     88     31     37
# 27    332    280   4.40   6.65   6.16    140    140     33     41
# 28    332    315   4.93   6.65   6.50    139    176     41     34
# 29    332    280   4.93   6.65   6.16    176    140     34     41
#
# [30 rows x 28 columns]

# %%
import importlib
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
candidate_roots = [ROOT, *ROOT.parents, Path('/storage/viet/FreeBindCraft').resolve()]
ADDITIONS = None
for base in candidate_roots:
    candidate = base / 'dependencies' / 'IPSAE' / 'additions'
    if (candidate / 'ipsae_comparison_ui.py').exists():
        ADDITIONS = candidate
        break

if ADDITIONS is None:
    raise FileNotFoundError('Could not find dependencies/IPSAE/additions/ipsae_comparison_ui.py')

if str(ADDITIONS) not in sys.path:
    sys.path.insert(0, str(ADDITIONS))

import ipsae_comparison_ui

importlib.reload(ipsae_comparison_ui)
ipsae_comparison_ui.launch_ipsae_comparison_ui()
# Out:
# VBox(children=(HTML(value='<div style="background:#e8d5f5;padding:12px 16px;border-radius:6px;margin:8px 0;fon…
# <div style="color:#57606a;;margin:8px 0;font-family:sans-serif">Ready. Choose a metrics folder, then summarize to show results here.</div>
# <b>models evaluation ranked by ipSAE score</b>
#                                                 Model Chn1 Chn2  Type  \
# 24  fold_ifit5_1half_altered2_binder_l88_s481314_m...    A    B  asym
# 21  fold_ifit5_1half_altered2_binder_l88_s481314_m...    A    B  asym
# 0   fold_ifit5_1half_altered2_binder_l130_s734871_...    A    B  asym
# 3   fold_ifit5_1half_altered2_binder_l130_s734871_...    A    B  asym
# 18  fold_ifit5_1half_altered2_binder_l150_s62602_m...    A    B  asym
# 6   fold_ifit5_1half_altered2_binder_l136_s450785_...    A    B  asym
# 15  fold_ifit5_1half_altered2_binder_l150_s62602_m...    A    B  asym
# 28  fold_ifit5_with_ifit5_1half_altered2_binder_l1...    B    A  asym
# 10  fold_ifit5_1half_altered2_binder_l136_s450785_...    B    A  asym
# 13  fold_ifit5_1half_altered2_binder_l142_s405521_...    B    A  asym
#
#        ipSAE  ipTM_af  pDockQ     LIS  \
# 24  0.812987     0.93  0.5119  0.7004
# 21  0.812041     0.93  0.5065  0.6958
# 0   0.808158     0.90  0.4310  0.6398
# 3   0.791097     0.89  0.3884  0.6269
# 18  0.780926     0.88  0.4781  0.5766
# 6   0.723004     0.85  0.4106  0.5229
# 15  0.671827     0.83  0.3953  0.5505
# 28  0.546986     0.79  0.3618  0.4629
# 10  0.011191     0.24  0.2093  0.0677
# 13  0.010305     0.42  0.2206  0.0629
#
#                                            Score_File
# 24  bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
# 21  bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
# 0   bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
# 3   bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
# 18  bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
# 6   bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
# 15  bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
# 28  bulk_ipsae_evals_20260727_191404/fold_ifit5_wi...
# 10  bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
# 13  bulk_ipsae_evals_20260727_191404/fold_ifit5_1h...
